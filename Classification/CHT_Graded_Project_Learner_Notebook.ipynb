# %% [markdown]
# # **Project - Classification and Hypothesis Testing: Hotel Booking Cancellation Prediction**
#
# ---------------
# ## **Problem Statement**
#
# ### **Context**
#
# **A significant number of hotel bookings are called off due to cancellations or no-shows.** Typical reasons for cancellations include change of plans, scheduling conflicts, etc. This is often made easier by the option to do so free of charge or preferably at a low cost. This may be beneficial to hotel guests, but it is a less desirable and possibly revenue-diminishing factor for hotels to deal with. Such losses are particularly high on last-minute cancellations.
#
# The new technologies involving online booking channels have dramatically changed customers’ booking possibilities and behavior. This adds a further dimension to the challenge of how hotels handle cancellations, which are no longer limited to traditional booking and guest characteristics.
#
# This pattern of cancellations of bookings impacts a hotel on various fronts:
# 1. **Loss of resources (revenue)** when the hotel cannot resell the room.
# 2. **Additional costs of distribution channels** by increasing commissions or paying for publicity to help sell these rooms.
# 3. **Lowering prices last minute**, so the hotel can resell a room, resulting in reducing the profit margin.
# 4. **Human resources to make arrangements** for the guests.
#
# ### **Objective**
#
# This increasing number of cancellations calls for a Machine Learning based solution that can help in predicting which booking is likely to be canceled. INN Hotels Group has a chain of hotels in Portugal - they are facing problems with this high number of booking cancellations and have reached out to your firm for data-driven solutions. You, as a Data Scientist, have to analyze the data provided to find which factors have a high influence on booking cancellations, build a predictive model that can predict which booking is going to be canceled in advance, and help in formulating profitable policies for cancellations and refunds.
#
#
# ### **Data Description**
#
# The data contains the different attributes of customers' booking details. The detailed data dictionary is given below:
#
#
# **Data Dictionary**
#
# * **Booking_ID:** Unique identifier of each booking
# * **no_of_adults:** Number of adults
# * **no_of_children:** Number of children
# * **no_of_weekend_nights:** Number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the hotel
# * **no_of_week_nights:** Number of weekday nights (Monday to Friday) the guest stayed or booked to stay at the hotel
# * **type_of_meal_plan:** Type of meal plan booked by the customer:
#     * Not Selected – No meal plan selected
#     * Meal Plan 1 – Breakfast
#     * Meal Plan 2 – Half board (breakfast and one other meal)
#     * Meal Plan 3 – Full board (breakfast, lunch, and dinner)
# * **required_car_parking_space:** Does the customer require a car parking space? (0 - No, 1- Yes)
# * **room_type_reserved:** Type of room reserved by the customer. The values are ciphered (encoded) by INN Hotels.
# * **lead_time:** Number of days between the date of booking and the arrival date
# * **arrival_year:** Year of arrival date
# * **arrival_month:** Month of arrival date
# * **arrival_date:** Date of the month
# * **market_segment_type:** Market segment designation.
# * **repeated_guest:** Is the customer a repeated guest? (0 - No, 1- Yes)
# * **no_of_previous_cancellations:** Number of previous bookings that were canceled by the customer prior to the current booking
# * **no_of_previous_bookings_not_canceled:** Number of previous bookings not canceled by the customer prior to the current booking
# * **avg_price_per_room:** Average price per day of the reservation; prices of the rooms are dynamic. (in euros)
# * **no_of_special_requests:** Total number of special requests made by the customer (e.g. high floor, view from the room, etc)
# * **booking_status:** Flag indicating if the booking was canceled or not.

# %% [markdown]
# ## **Importing the libraries required**

# %%
# Importing the basic libraries we will require for the project

# Libraries to help with reading and manipulating data
import pandas as pd
import numpy as np

# Libaries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# Importing the Machine Learning models we require from Scikit-Learn
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier

# Importing the other functions we may require from Scikit-Learn
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import MinMaxScaler, LabelEncoder, OneHotEncoder

# To get diferent metric scores
from sklearn.metrics import confusion_matrix,classification_report,roc_auc_score,plot_confusion_matrix,precision_recall_curve,roc_curve,make_scorer

# Code to ignore warnings from function usage
import warnings;
import numpy as np
warnings.filterwarnings('ignore')

# %% [markdown]
# ## **Loading the dataset**

# %%
hotel = pd.read_csv("INNHotelsGroup.csv")

# %%
# Copying data to another variable to avoid any changes to original data
data = hotel.copy()

# %% [markdown]
# ## **Overview of the dataset**

# %% [markdown]
# ### **View the first and last 5 rows of the dataset**
#
# Let's **view the first few rows and last few rows** of the dataset in order to understand its structure a little better.
#
# We will use the head() and tail() methods from Pandas to do this.

# %%
data.head()
# Out:
#   Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0   INN00001             2               0                     1
# 1   INN00002             2               0                     2
# 2   INN00003             1               0                     2
# 3   INN00004             2               0                     0
# 4   INN00005             2               0                     1
#
#    no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                  2       Meal Plan 1                           0
# 1                  3      Not Selected                           0
# 2                  1       Meal Plan 1                           0
# 3                  2       Meal Plan 1                           0
# 4                  1      Not Selected                           0
#
#   room_type_reserved  lead_time  arrival_year  arrival_month  arrival_date  \
# 0        Room_Type 1        224          2017             10             2
# ...

# %%
data.tail()
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 36270   INN36271             3               0                     2
# 36271   INN36272             2               0                     1
# 36272   INN36273             2               0                     2
# 36273   INN36274             2               0                     0
# 36274   INN36275             2               0                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 36270                  6       Meal Plan 1                           0
# 36271                  3       Meal Plan 1                           0
# 36272                  6       Meal Plan 1                           0
# 36273                  3      Not Selected                           0
# 36274                  2       Meal Plan 1                           0
#
#       room_type_reserved  lead_time  arrival_year  arrival_month  \
# ...

# %% [markdown]
# ### **Understand the shape of the dataset**

# %%
data.shape
# Out:
# (36275, 19)

# %% [markdown]
# * The dataset has 36275 rows and 19 columns.

# %% [markdown]
# ### **Check the data types of the columns for the dataset**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36275 entries, 0 to 36274
# Data columns (total 19 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Booking_ID                            36275 non-null  object
#  1   no_of_adults                          36275 non-null  int64
#  2   no_of_children                        36275 non-null  int64
#  3   no_of_weekend_nights                  36275 non-null  int64
#  4   no_of_week_nights                     36275 non-null  int64
#  5   type_of_meal_plan                     36275 non-null  object
#  6   required_car_parking_space            36275 non-null  int64
#  7   room_type_reserved                    36275 non-null  object
#  8   lead_time                             36275 non-null  int64
#  9   arrival_year                          36275 non-null  int64
#  10  arrival_month                         36275 non-null  int64
# ...

# %% [markdown]
# * `Booking_ID`, `type_of_meal_plan`, `room_type_reserved`, `market_segment_type`, and `booking_status` are of object type while rest columns are numeric in nature.
#
# * There are no null values in the dataset.

# %% [markdown]
# ### **Dropping duplicate values**

# %%
# checking for duplicate values
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# - There are **no duplicate values** in the data.

# %% [markdown]
# ### **Dropping the unique values column**

# %% [markdown]
# **Let's drop the Booking_ID column first before we proceed forward**, as a column with unique values will have almost no predictive power for the Machine Learning problem at hand.

# %%
data = data.drop(["Booking_ID"], axis=1)

# %%
data.head()
# Out:
#    no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0             2               0                     1                  2
# 1             2               0                     2                  3
# 2             1               0                     2                  1
# 3             2               0                     0                  2
# 4             2               0                     1                  1
#
#   type_of_meal_plan  required_car_parking_space room_type_reserved  lead_time  \
# 0       Meal Plan 1                           0        Room_Type 1        224
# 1      Not Selected                           0        Room_Type 1          5
# 2       Meal Plan 1                           0        Room_Type 1          1
# 3       Meal Plan 1                           0        Room_Type 1        211
# 4      Not Selected                           0        Room_Type 1         48
#
# ...

# %% [markdown]
# ### **1: Check the summary statistics of the dataset and write your observations**

# %% [markdown]
# **Let's check the statistical summary of the data.**

# %%
data.describe().T
# Out:
#                                         count         mean        std     min  \
# no_of_adults                          36275.0     1.844962   0.518715     0.0
# no_of_children                        36275.0     0.105279   0.402648     0.0
# no_of_weekend_nights                  36275.0     0.810724   0.870644     0.0
# no_of_week_nights                     36275.0     2.204300   1.410905     0.0
# required_car_parking_space            36275.0     0.030986   0.173281     0.0
# lead_time                             36275.0    85.232557  85.930817     0.0
# arrival_year                          36275.0  2017.820427   0.383836  2017.0
# arrival_month                         36275.0     7.423653   3.069894     1.0
# arrival_date                          36275.0    15.596995   8.740447     1.0
# repeated_guest                        36275.0     0.025637   0.158053     0.0
# no_of_previous_cancellations          36275.0     0.023349   0.368331     0.0
# ...

# %% [markdown]
# 1. In almost all the Feature the mean and the median are very similar, this implies that we have, in general, good normal distributions. This also implies that there will be no important outlier (neither too big nor too many). The only exception for which this is untrue are "lead_time" and "avg_price_per_room" where the difference between the 2 main central tendencies is evident.
#
# 2. Booking Status being a Categorical variable is not present, so to check if the dataset is biased toward cancellation or not should be checked

# %% [markdown]
# ## **Exploratory Data Analysis**

# %% [markdown]
# ### **2: Univariate Analysis**

# %% [markdown]
# Let's explore these variables in some more depth by observing their distributions.

# %% [markdown]
# We will first define a **hist_box() function** that provides both a boxplot and a histogram in the same visual, with which we can perform univariate analysis on the columns of this dataset.

# %%
# Defining the hist_box() function
def hist_box(data,col):
  f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={'height_ratios': (0.15, 0.85)}, figsize=(12,6))
  # Adding a graph in each part
  sns.boxplot(data[col], ax=ax_box, showmeans=True)
  sns.distplot(data[col], ax=ax_hist)
  plt.show()

# %% [markdown]
# #### **Question 2.1:  Plot the histogram and box plot for the variable `Lead Time` using the hist_box function provided and write your insights. **

# %%
hist_box(data, 'lead_time')

# %% [markdown]
# - As it was previously shown, the means and the median do not coincide or at least are very close. Because there are so many outliers
#
# - The distribution for the lead time (Number of days between the date of booking and the arrival date) is very right-skewed

# %% [markdown]
# #### **2.2:  Plot the histogram and box plot for the variable `Average Price per Room` using the hist_box function provided and write your insights.**

# %%
hist_box(data, 'avg_price_per_room')

# %% [markdown]
# - Similarly, also this feature was previuosly flagged because it has a mean higher than the median.
#
# - The distribution for the Average Price per Room is right-skewed
#
# - The Average Price per Room features has many outliers. But contrary to lead time, its outliers more or less counter-balance each other

# %% [markdown]
# **Interestingly some rooms have a price equal to 0. Let's check them.**

# %%
data[data["avg_price_per_room"] == 0]
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 63                1               0                     0                  1
# 145               1               0                     0                  2
# 209               1               0                     0                  0
# 266               1               0                     0                  2
# 267               1               0                     2                  1
# ...             ...             ...                   ...                ...
# 35983             1               0                     0                  1
# 36080             1               0                     1                  1
# 36114             1               0                     0                  1
# 36217             2               0                     2                  1
# 36250             1               0                     0                  2
#
# ...

# %% [markdown]
# - There are quite a few hotel rooms which have a price equal to 0.
# - In the market segment column, it looks like many values are complementary.

# %%
data.loc[data["avg_price_per_room"] == 0, "market_segment_type"].value_counts()
# Out:
# Complementary    354
# Online           191
# Name: market_segment_type, dtype: int64

# %% [markdown]
# * It makes sense that most values with room prices equal to 0 are the rooms given as complimentary service from the hotel.
# * The rooms booked online must be a part of some promotional campaign done by the hotel.

# %%
# Calculating the 25th quantile
Q1 = data["avg_price_per_room"].quantile(0.25)

# Calculating the 75th quantile
Q3 = data["avg_price_per_room"].quantile(0.75)

# Calculating IQR
IQR = Q3 - Q1

# Calculating value of upper whisker
Upper_Whisker = Q3 + 1.5 * IQR
Upper_Whisker
# Out:
# 179.55

# %%
data.loc[data["avg_price_per_room"] >= 500, "avg_price_per_room"]
# Out:
# 33114    540.0
# Name: avg_price_per_room, dtype: float64

# %%
# assigning the outliers the value of upper whisker
# first part to locate the data
# then comma to choose the Specific Column so that you can assign the value to just that feature and not the overall column
data.loc[data["avg_price_per_room"] >= 500, "avg_price_per_room"] = Upper_Whisker

# %% [markdown]
# #### **Let's understand the distribution of the categorical variables**

# %% [markdown]
# **Number of Children**

# %%
sns.countplot(data['no_of_children'])
plt.show()

# %%
data['no_of_children'].value_counts(normalize=True)
# Out:
# 0     0.925624
# 1     0.044604
# 2     0.029166
# 3     0.000524
# 9     0.000055
# 10    0.000028
# Name: no_of_children, dtype: float64

# %% [markdown]
# * Customers were not travelling with children in 93% of cases.
# * There are some values in the data where the number of children is 9 or 10, which is highly unlikely.
# * We will replace these values with the maximum value of 3 children.

# %%
# replacing 9, and 10 children with 3

# replace works like in any strings or list
data["no_of_children"] = data["no_of_children"].replace([9, 10], 3)

# %% [markdown]
# **Arrival Month**

# %%
sns.countplot(data["arrival_month"])
plt.show()

# %%
data['arrival_month'].value_counts(normalize=True)
# Out:
# 10    0.146575
# 9     0.127112
# 8     0.105114
# 6     0.088298
# 12    0.083280
# 11    0.082150
# 7     0.080496
# 4     0.075424
# 5     0.071620
# 3     0.065003
# 2     0.046975
# 1     0.027953
# Name: arrival_month, dtype: float64

# %% [markdown]
# * October is the busiest month for hotel arrivals followed by September and August. **Over 35% of all bookings**, as we see in the above table, were for one of these three months.
# * Around 14.7% of the bookings were made for an October arrival.

# %% [markdown]
# **Booking Status**

# %%
sns.countplot(data["booking_status"])
plt.show()

# %%
data['booking_status'].value_counts(normalize=True)
# Out:
# Not_Canceled    0.672364
# Canceled        0.327636
# Name: booking_status, dtype: float64

# %% [markdown]
# * 32.8% of the bookings were canceled by the customers.

# %% [markdown]
# **Let's encode Canceled bookings to 1 and Not_Canceled as 0 for further analysis**

# %%
# .apply is a function that you apply on the dataset directly ONE VALUE AT A TIME
data["booking_status"] = data["booking_status"].apply(
    lambda x: 1 if x == "Canceled" else 0
)

# %% [markdown]
# ### **3: Bivariate Analysis**

# %% [markdown]
# #### **3.1: Find and visualize the correlation matrix using a heatmap and write your observations from the plot.**

# %%
cols_list = data.select_dtypes(include=np.number).columns.tolist()
cols_list
# Out:
# ['no_of_adults',
#  'no_of_children',
#  'no_of_weekend_nights',
#  'no_of_week_nights',
#  'required_car_parking_space',
#  'lead_time',
#  'arrival_year',
#  'arrival_month',
#  'arrival_date',
#  'repeated_guest',
#  'no_of_previous_cancellations',
#  'no_of_previous_bookings_not_canceled',
#  'avg_price_per_room',
#  'no_of_special_requests',
#  'booking_status']

# %%
cols_list = data.select_dtypes(include=np.number).columns.tolist()

plt.figure(figsize=(12, 7))
sns.heatmap(data[cols_list].corr() , annot=True, vmin=-1, vmax=1, fmt=".2f", cmap="Spectral")
plt.show()

# %% [markdown]
# - There is a slight correlation between the number of children or number of adults with the average price of a room. This slight correlation, clearly, does make sense since more people are in a room, more the price of the room increases.
#
# - There are 2 good positive correlation between repeated guest and number of previous cancellation or number of previous booking not canceled. Both are clear since, an usual guest may cancel a booking, in order to simply shift it forward in the future. On a similar note, an usual guest will obviously have a high number of previous cancellation or number of previous booking not canceled.
#
#
# -  There is a positive correlation between the Lead time (the number of days between the date of booking and the arrival date) and the booking status. This correlation highlight that a very early booking can result in a cancellation.

# %% [markdown]
# **Hotel rates are dynamic and change according to demand and customer demographics. Let's see how prices vary across different market segments**

# %%
plt.figure(figsize=(10, 6)) 
sns.boxplot(
    data=data, x="market_segment_type", y="avg_price_per_room", palette="gist_rainbow"
)
plt.show()

# %% [markdown]
# * Rooms booked online have high variations in prices.
# * The offline and corporate room prices are almost similar.
# * Complementary market segment gets the rooms at very low prices, which makes sense.

# %% [markdown]
# We will define a **stacked barplot()** function to help analyse how the target variable varies across predictor categories.

# %%
# Defining the stacked_barplot() function
def stacked_barplot(data,predictor,target,figsize=(10,6)):
    (pd.crosstab(data[predictor],data[target],normalize='index')*100).plot(kind='bar',figsize=figsize,stacked=True)
    plt.legend(loc="lower right")
    plt.ylabel('Percentage Cancellations %')

# %% [markdown]
# #### **3.2: Plot the stacked barplot for the variable `Market Segment Type` against the target variable `Booking Status` using the stacked_barplot  function provided and write your insights. **

# %%
stacked_barplot(data, 'market_segment_type', 'booking_status')

# %% [markdown]
# - Online and Offline markets have an higher cancellation rate respect to complementary or corporate. This make sense, since in one case the booking is free and in the second case the booking is probably payed from the corporation and it has a specific goal.

# %% [markdown]
# #### **3.3: Plot the stacked barplot for the variable `Repeated Guest` against the target variable `Booking Status` using the stacked_barplot  function provided and write your insights.**
#
# Repeating guests are the guests who stay in the hotel often and are important to brand equity.

# %%
stacked_barplot(data, 'repeated_guest', 'booking_status')

# %% [markdown]
# - Repeat guest do not cancel the booking veru often to not regular guest. This is obvious since regular guest are already satisfied with the hotel/structure.

# %% [markdown]
# **Let's analyze the customer who stayed for at least a day at the hotel.**

# %%
stay_data = data[(data["no_of_week_nights"] > 0) & (data["no_of_weekend_nights"] > 0)]
stay_data["total_days"] = (stay_data["no_of_week_nights"] + stay_data["no_of_weekend_nights"])

stacked_barplot(stay_data, "total_days", "booking_status",figsize=(15,6))

# %% [markdown]
# * The general trend is that the chances of cancellation increase as the number of days the customer planned to stay at the hotel increases.

# %% [markdown]
# **As hotel room prices are dynamic, Let's see how the prices vary across different months**

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(y=data["avg_price_per_room"], x=data["arrival_month"], ci=None)
plt.show()

# %% [markdown]
# * The price of rooms is highest in May to September - around 115 euros per room.

# %% [markdown]
# ## **Data Preparation for Modeling**
#
# - We want to predict which bookings will be canceled.
# - Before we proceed to build a model, we'll have to encode categorical features.
# - We'll split the data into train and test to be able to evaluate the model that we build on the train data.

# %% [markdown]
# **Separating the independent variables (X) and the dependent variable (Y)**

# %%
X = data.drop(["booking_status"], axis=1)
Y = data["booking_status"]

X = pd.get_dummies(X, drop_first=True) # Encoding the Categorical features

# %% [markdown]
# **Splitting the data into a 70% train and 30% test set**
#
# Some classification problems can exhibit a large imbalance in the distribution of the target classes: for instance there could be several times more negative samples than positive samples. In such cases it is recommended to use the **stratified sampling** technique to ensure that relative class frequencies are approximately preserved in each train and validation fold.

# %%
# Splitting data in train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.30,stratify=Y, random_state=1)

# %%
print("Shape of Training set : ", X_train.shape)
print("Shape of test set : ", X_test.shape)
print("Percentage of classes in training set:")
print(y_train.value_counts(normalize=True))
print("Percentage of classes in test set:")
print(y_test.value_counts(normalize=True))
# Out:
# Shape of Training set :  (25392, 27)
# Shape of test set :  (10883, 27)
# Percentage of classes in training set:
# 0    0.672377
# 1    0.327623
# Name: booking_status, dtype: float64
# Percentage of classes in test set:
# 0    0.672333
# 1    0.327667
# Name: booking_status, dtype: float64

# %% [markdown]
# ## **Model Evaluation Criterion**
#
# #### **Model can make wrong predictions as:**
#
# 1. Predicting a customer will not cancel their booking but in reality, the customer will cancel their booking.
# 2. Predicting a customer will cancel their booking but in reality, the customer will not cancel their booking.
#
# #### **Which case is more important?**
#
# Both the cases are important as:
#
# * If we predict that a booking will not be canceled and the booking gets canceled then the hotel will lose resources and will have to bear additional costs of distribution channels.
#
# * If we predict that a booking will get canceled and the booking doesn't get canceled the hotel might not be able to provide satisfactory services to the customer by assuming that this booking will be canceled. This might damage brand equity.
#
#
#
# #### **How to reduce the losses?**
#
# * The hotel would want the `F1 Score` to be maximized, the greater the F1  score, the higher the chances of minimizing False Negatives and False Positives.

# %% [markdown]
# **Also, let's create a function to calculate and print the classification report and confusion matrix so that we don't have to rewrite the same code repeatedly for each model.**

# %%
# Creating metric function 
def metrics_score(actual, predicted):
    print(classification_report(actual, predicted))

    cm = confusion_matrix(actual, predicted)
    plt.figure(figsize=(8,5))
    
    sns.heatmap(cm, annot=True,  fmt='.2f', xticklabels=['Not Cancelled', 'Cancelled'], yticklabels=['Not Cancelled', 'Cancelled'])
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.show()

# %% [markdown]
# ## **Building the model**
#
# We will be building 4 different models:
#
# - **Logistic Regression**
# - **Support Vector Machine (SVM)**
# - **Decision Tree**
# - **Random Forest**

# %% [markdown]
# ### **4: Logistic Regression**

# %% [markdown]
# #### **4.1: Build a Logistic Regression model (Use the sklearn library)**

# %%
# Remove _________ and complete the code

# Fitting logistic regression model
lg = LogisticRegression()
lg.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# #### **4.2: Check the performance of the model on train and test data **

# %%
# Checking the performance on the training data
y_pred_train = lg.predict(X_train)  #X_train, X_test, y_train, y_test
metrics_score(y_train, y_pred_train)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.90      0.86     17073
#            1       0.74      0.61      0.66      8319
#
#     accuracy                           0.80     25392
#    macro avg       0.78      0.75      0.76     25392
# weighted avg       0.80      0.80      0.79     25392

# %% [markdown]
# - We were able to build a predictive model that can be used by the Hotel to predict the cusomers who are likely to cancel the booking with a recall (proportion of actual cancellation found) of 61% and a precision of 74%.

# %% [markdown]
# Let's check the performance on the test set

# %%
# Checking the performance on the test dataset
y_pred_test = lg.predict(X_test)
metrics_score(y_test, y_pred_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.89      0.85      7317
#            1       0.73      0.60      0.66      3566
#
#     accuracy                           0.79     10883
#    macro avg       0.77      0.74      0.75     10883
# weighted avg       0.79      0.79      0.79     10883

# %% [markdown]
# - The model we have created was clearly not overfitted since it generalized well and gave similar Precision and Recall scores.
# - It is possible that the model can be still improved
# - The Model most likely has a Precision-Recall trade-off to be considered

# %% [markdown]
# #### **4.3: Find the optimal threshold for the model using the Precision-Recall Curve. **
#
# Precision-Recall curves summarize the trade-off between the true positive rate and the positive predictive value for a predictive model using different probability thresholds.
#
# Let's use the Precision-Recall curve and see if we can find a **better threshold.**

# %%
# Predict_proba gives the probability of each observation belonging to each class
y_scores_lg=lg.predict_proba(X_train)

precisions_lg, recalls_lg, thresholds_lg = precision_recall_curve(y_train, y_scores_lg[:,1])

# Plot values of precisions, recalls, and thresholds
plt.figure(figsize=(10,7))
plt.plot(thresholds_lg, precisions_lg[:-1], 'b--', label='precision')
plt.plot(thresholds_lg, recalls_lg[:-1], 'g--', label = 'recall')
plt.xlabel('Threshold')
plt.legend(loc='upper left')
plt.ylim([0,1])
point_x_coord = thresholds_lg[precisions_lg[:-1] == recalls_lg[:-1]][0] # Method to find the Threshold value where the condition is met
point_y_coord = precisions_lg[:-1][precisions_lg[:-1] == recalls_lg[:-1]][0]
print(f'The Intersection point between Precision and Recall is {point_x_coord}')
plt.plot(point_x_coord, point_y_coord, 'o')
plt.vlines(0.3, 0.6, 0.8)
plt.show()
# Out:
# The Intersection point between Precision and Recall is 0.42075003198663524

# %% [markdown]
# - We want to choose a threshold that has a high recall while also having a small drop in precision. Thus, we chose a value slightly smaller (in absolute value) than the intersection point between the Precision and Recall line.
#
# - We choose for this reason a Threshold value of 0.38

# %%
# Setting the optimal threshold
optimal_threshold = 0.38

# %% [markdown]
# #### **4.4: Check the performance of the model on train and test data using the optimal threshold.**

# %%
# Creating confusion matrix
y_pred_train = lg.predict_proba(X_train)
metrics_score(y_train, y_pred_train[:,1] > optimal_threshold)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.82      0.84     17073
#            1       0.66      0.73      0.70      8319
#
#     accuracy                           0.79     25392
#    macro avg       0.76      0.77      0.77     25392
# weighted avg       0.80      0.79      0.79     25392

# %% [markdown]
# - With this new Threshold, we are, now, able to build a predictive model that can be used by the Hotel to predict the cusomers, who are likely to cancel the booking, with a recall (proportion of actual cancellation found) of 73% (from 60%). That has reduced its precision to 66% (from 73%)

# %% [markdown]
# Let's check the performance on the test set

# %%
y_pred_test = lg.predict_proba(X_test)
metrics_score(y_test,y_pred_test[:,1] > optimal_threshold)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.82      0.84      7317
#            1       0.66      0.72      0.69      3566
#
#     accuracy                           0.78     10883
#    macro avg       0.76      0.77      0.76     10883
# weighted avg       0.79      0.78      0.79     10883

# %% [markdown]
# - As, we said before, the model was not overfitted and thus it was able to generalize correctly.
# - The new model, thus, is now able to have even a higher Recall, about 72%, for the cancelled reservation.

# %% [markdown]
# ### **5: Support Vector Machines**

# %% [markdown]
# To accelerate SVM training, let's scale the data for support vector machines.

# %%
scaling = MinMaxScaler(feature_range=(-1,1)).fit(X_train)
X_train_scaled = scaling.transform(X_train)
X_test_scaled = scaling.transform(X_test)

# %% [markdown]
# Let's build the models using the two of the widely used kernel functions:
#
# 1.   **Linear Kernel**
# 2.   **RBF Kernel**

# %% [markdown]
# #### **5.1: Build a Support Vector Machine model using a linear kernel**

# %% [markdown]
# **Note: Please use the scaled data for modeling Support Vector Machine**

# %%
svm = SVC(kernel='linear',probability=True) # Linear kernal or linear decision boundary
model = svm.fit(X= X_train_scaled, y = y_train)

# %% [markdown]
# #### **5.2: Check the performance of the model on train and test data**

# %%
y_pred_train_svm = model.predict(X_train_scaled)
metrics_score(y_train, y_pred_train_svm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.90      0.86     17073
#            1       0.74      0.61      0.67      8319
#
#     accuracy                           0.80     25392
#    macro avg       0.79      0.76      0.77     25392
# weighted avg       0.80      0.80      0.80     25392

# %% [markdown]
# - The new linear SVM Model has no effective improvement respect to the Logistic Regression one. It has instead a quite big downside since it is much slower.
#
# - The previous consideration holds also in this case since both the Precision and Recall score are almost the same
#
# - We were able to build a predictive model that can be used by the Hotel to predict the cusomers who are likely to cancel the booking with a recall (proportion of actual cancellation found) of 61% and a precision of 74%

# %% [markdown]
# Checking model performance on test set

# %%
y_pred_test_svm = model.predict(X_test_scaled)
metrics_score(y_test, y_pred_test_svm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.90      0.86      7317
#            1       0.74      0.61      0.67      3566
#
#     accuracy                           0.80     10883
#    macro avg       0.78      0.75      0.76     10883
# weighted avg       0.80      0.80      0.80     10883

# %% [markdown]
# - The model is able to predict the cusomers who are likely to cancel the booking with a recall (proportion of actual cancellation found) of 61% and a precision of 74%

# %% [markdown]
# #### **5.3: Find the optimal threshold for the model using the Precision-Recall Curve.**

# %%
# Predict on train data
y_scores_svm=model.predict_proba(X_train_scaled)

precisions_svm, recalls_svm, thresholds_svm = precision_recall_curve(y_train, y_scores_svm[:,1])

# Plot values of precisions, recalls, and thresholds
plt.figure(figsize=(10,7))
plt.plot(thresholds_svm, precisions_svm[:-1], 'b--', label='precision')
plt.plot(thresholds_svm, recalls_svm[:-1], 'g--', label = 'recall')
plt.xlabel('Threshold')
plt.legend(loc='upper left')
plt.ylim([0,1])
point_x_coord = thresholds_svm[precisions_svm[:-1] == recalls_svm[:-1]][0] # Method to find the Threshold value where the condition is met
point_y_coord = precisions_svm[:-1][precisions_svm[:-1] == recalls_svm[:-1]][0]
print(f'The Intersection point between Precision and Recall is {point_x_coord}')
plt.plot(point_x_coord, point_y_coord, 'o')
plt.vlines(0.3, 0.6, 0.8)
plt.show()
# Out:
# The Intersection point between Precision and Recall is 0.4091148344098479

# %% [markdown]
# - We want to choose a threshold that has a high recall while also having a small drop in precision. Thus, we chose a value slightly smaller (in absolute value) than the intersection point between the Precision and Recall line.
#
# - We choose for this reason a Threshold value of 0.38

# %%
optimal_threshold_svm=0.38

# %% [markdown]
# #### **5.4: Check the performance of the model on train and test data using the optimal threshold.**

# %%
y_pred_train_svm = model.predict_proba(X_train_scaled)
metrics_score(y_train, y_pred_train_svm[:,1] > optimal_threshold_svm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.83      0.85     17073
#            1       0.68      0.72      0.70      8319
#
#     accuracy                           0.80     25392
#    macro avg       0.77      0.78      0.77     25392
# weighted avg       0.80      0.80      0.80     25392

# %% [markdown]
# - With this new Threshold, we are, now, able to build a predictive model that can be used by the Hotel to predict the cusomers, who are likely to cancel the booking, with a recall (proportion of actual cancellation found) of 72% (from 61%). That has reduced its precision to 68% (from 74%)
#
# - This new model is more performing for our goal.
#
# - It is important to underline that this model is very similar, from a predictive power point of view, to the previous one (Logistic Regression)

# %%
y_pred_test = model.predict_proba(X_test_scaled)
metrics_score(y_test, y_pred_test[:,1] > optimal_threshold_svm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.82      0.84      7317
#            1       0.67      0.72      0.69      3566
#
#     accuracy                           0.79     10883
#    macro avg       0.76      0.77      0.77     10883
# weighted avg       0.80      0.79      0.79     10883

# %% [markdown]
# - With this new Threshold, we are, now, able to build a predictive model that can be used by the Hotel to predict the cusomers, who are likely to cancel the booking, with a recall (proportion of actual cancellation found) of 72% (from 61%). That has reduced its precision to 67% (from 74%)
#
# - This new model is more performing for our goal.
#
# - It is important to underline that this model is very similar, from a predictive power point of view, to the previous one (Logistic Regression)

# %% [markdown]
# #### **5.5: Build a Support Vector Machines model using an RBF kernel**

# %%
svm_rbf=SVC(kernel='rbf',probability=True)
svm_rbf.fit(X_train_scaled, y_train)
# Out:
# SVC(probability=True)

# %% [markdown]
# #### **5.6: Check the performance of the model on train and test data**

# %%
y_pred_train_svm = svm_rbf.predict(X_train_scaled)
metrics_score(y_train, y_pred_train_svm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.91      0.88     17073
#            1       0.79      0.65      0.71      8319
#
#     accuracy                           0.83     25392
#    macro avg       0.81      0.78      0.80     25392
# weighted avg       0.82      0.83      0.82     25392

# %% [markdown]
# - The new RBF SVM Model has a slight improvement respect to the previous Linear SVM model. It has, still, the quite big downside of being slow.
#
# - We were able to build a better predictive model that can be used by the Hotel to predict the cusomers who are likely to cancel the booking with a recall (proportion of actual cancellation found) of 65% and a precision of 79%

# %% [markdown]
# #### Checking model performance on test set

# %%
y_pred_test = svm_rbf.predict(X_test_scaled)
metrics_score(y_test, y_pred_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.91      0.87      7317
#            1       0.78      0.63      0.70      3566
#
#     accuracy                           0.82     10883
#    macro avg       0.81      0.77      0.78     10883
# weighted avg       0.82      0.82      0.81     10883

# %% [markdown]
# - We were able to predict how likely are the costumer to cancel the booking with a Recall (proportion of actual cancellation found) of 63%.
#
# - This Model, as in the previous cases, can still be improved adding a Threshold

# %%
# Predict on train data
y_scores_svm=svm_rbf.predict_proba(X_train_scaled)

precisions_svm, recalls_svm, thresholds_svm = precision_recall_curve(y_train, y_scores_svm[:,1])

# Plot values of precisions, recalls, and thresholds
plt.figure(figsize=(10,7))
plt.plot(thresholds_svm, precisions_svm[:-1], 'b--', label='precision')
plt.plot(thresholds_svm, recalls_svm[:-1], 'g--', label = 'recall')
plt.xlabel('Threshold')
plt.legend(loc='upper left')
plt.ylim([0,1])
point_x_coord = thresholds_svm[precisions_svm[:-1] == recalls_svm[:-1]][0] # Method to find the Threshold value where the condition is met
point_y_coord = precisions_svm[:-1][precisions_svm[:-1] == recalls_svm[:-1]][0]
print(f'The Intersection point between Precision and Recall is {point_x_coord}')
plt.plot(point_x_coord, point_y_coord, 'o')
plt.vlines(0.3, 0.6, 0.8)
plt.show()
# Out:
# The Intersection point between Precision and Recall is 0.40724793734331655

# %% [markdown]
# - We want to choose a threshold that has a high recall while also having a small drop in precision. Thus, we chose a value slightly smaller (in absolute value) than the intersection point between the Precision and Recall line.
#
# - We choose for this reason a Threshold value of 0.35

# %%
optimal_threshold_svm=0.35

# %% [markdown]
# #### **5.7: Check the performance of the model on train and test data using the optimal threshold.**

# %%
y_pred_train_svm = model.predict_proba(X_train_scaled)
metrics_score(y_train, y_pred_train_svm[:,1] > optimal_threshold_svm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.81      0.84     17073
#            1       0.66      0.74      0.70      8319
#
#     accuracy                           0.79     25392
#    macro avg       0.76      0.78      0.77     25392
# weighted avg       0.80      0.79      0.79     25392

# %% [markdown]
# - With this new Threshold, we are, now, able to build a predictive model that can be used by the Hotel to predict the cusomers, who are likely to cancel the booking, with a recall (proportion of actual cancellation found) of 74% (from 65%). That has reduced its precision to 66% (from 79%).
#
# - This new model is more performing for our goal.

# %%
y_pred_test = svm_rbf.predict_proba(X_test_scaled)
metrics_score(y_test, y_pred_test[:,1] > optimal_threshold_svm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.83      0.85      7317
#            1       0.69      0.76      0.72      3566
#
#     accuracy                           0.81     10883
#    macro avg       0.78      0.80      0.79     10883
# weighted avg       0.82      0.81      0.81     10883

# %% [markdown]
# - We were able to predict how likely are the costumer to cancel the booking with a Recall (proportion of actual cancellation found) of 76%.
#
# - This Model, as in the previous cases, has been greatly improved by the imposition of a Threshold

# %% [markdown]
# ### **6: Decision Trees**

# %% [markdown]
# #### **6.1: Build a Decision Tree Model**

# %%
model_dt = DecisionTreeClassifier()
model_dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# #### **6.2: Check the performance of the model on train and test data**

# %%
# Checking performance on the training dataset
pred_train_dt = model_dt.predict(X_train)
metrics_score(y_train, pred_train_dt)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     17073
#            1       1.00      0.99      0.99      8319
#
#     accuracy                           0.99     25392
#    macro avg       1.00      0.99      0.99     25392
# weighted avg       0.99      0.99      0.99     25392

# %% [markdown]
# * Very few errors on the training set, almost all samples have been classified correctly.
# * Model has performed very well on the training set.
# * As we know a decision tree will continue to grow and classify each data point correctly if no restrictions are applied as the trees will learn all the patterns in the training set.
# * The decision tree model is most likely overfitting. However the decision tree has better performance compared to Logistic Regression and SVM models.
# * Let's check the performance on test data to see if the model is overfitting

# %% [markdown]
# #### Checking model performance on test set

# %%
pred_test_dt = model_dt.predict(X_test)
metrics_score(y_test, pred_test_dt)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90      7317
#            1       0.79      0.80      0.80      3566
#
#     accuracy                           0.87     10883
#    macro avg       0.85      0.85      0.85     10883
# weighted avg       0.87      0.87      0.87     10883

# %% [markdown]
# - The Decision Tree was overfitting. However it displays very good prediction capabilities even respect to the other 2 previous model
#
# - In also it seems, in this case, there is no trade-off between Precision and Recall
#
# - Maybe by restricting the overfitting of the Decision Tree it is possible to obtain a better generalization

# %% [markdown]
#  #### **6.3: Perform hyperparameter tuning for the decision tree model using GridSearch CV**

# %% [markdown]
# **Note: Please use the following hyperparameters provided for tuning the Decision Tree. In general, you can experiment with various hyperparameters to tune the decision tree, but for this project, we recommend sticking to the parameters provided.**

# %%
# Choose the type of classifier.
estimator = DecisionTreeClassifier()

# Grid of parameters to choose from
parameters = {
    "max_depth": np.arange(2, 7, 2),
    "max_leaf_nodes": [50, 75, 150, 250],
    "min_samples_split": [10, 30, 50, 70],
}


# Run the grid search
grid_obj = GridSearchCV(estimator, parameters, verbose=5,n_jobs=-1)
grid_obj = grid_obj.fit(X_train, y_train)

# Set the clf to the best combination of parameters
estimator = grid_obj.best_estimator_

# Fit the best algorithm to the data.
estimator.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# DecisionTreeClassifier(max_depth=6, max_leaf_nodes=250, min_samples_split=10)

# %% [markdown]
# #### **6.4: Check the performance of the model on the train and test data using the tuned model**

# %% [markdown]
# #### Checking performance on the training set

# %%
# Checking performance on the training dataset
dt_tuned = estimator.predict(X_train)
metrics_score(y_train, dt_tuned)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.93      0.89     17073
#            1       0.82      0.68      0.75      8319
#
#     accuracy                           0.85     25392
#    macro avg       0.84      0.81      0.82     25392
# weighted avg       0.85      0.85      0.84     25392

# %% [markdown]
# - After restricting the growth of the Decision Tree, we see that the model No longer overfit the data.
# - We find a Recall score much lower to the previous one on the training set
#
# - If the predictive power has increased due to this reduction in overfitting, the process was worth it

# %%
# Checking performance on the training dataset
y_pred_tuned = estimator.predict(X_test)
metrics_score(y_test, y_pred_tuned)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.93      0.89      7317
#            1       0.82      0.67      0.74      3566
#
#     accuracy                           0.84     10883
#    macro avg       0.84      0.80      0.81     10883
# weighted avg       0.84      0.84      0.84     10883

# %% [markdown]
# - The new and restricted Decision Tree is performing, on unseen data, much worse than the previous unrestricted one.
#
# - It is probably best to keep the previous classifier or apply the cross-validation on the test set.

# %% [markdown]
# #### **Visualizing the Decision Tree**

# %%
feature_names = list(X_train.columns)
plt.figure(figsize=(20, 10))
out = tree.plot_tree(
    estimator,max_depth=3,
    feature_names=feature_names,
    filled=True,
    fontsize=9,
    node_ids=False,
    class_names=None,
)
# below code will add arrows to the decision tree split if they are missing
for o in out:
    arrow = o.arrow_patch
    if arrow is not None:
        arrow.set_edgecolor("black")
        arrow.set_linewidth(1)
plt.show()

# %% [markdown]
# #### **6.5: What are some important features based on the tuned decision tree?**

# %%
# Importance of features in the tree building

importances = estimator.feature_importances_
indices = np.argsort(importances)

plt.figure(figsize=(8, 8))
plt.title("Feature Importances")
plt.barh(range(len(indices)), importances[indices], color="violet", align="center")
plt.yticks(range(len(indices)), [feature_names[i] for i in indices])
plt.xlabel("Relative Importance")
plt.show()

# %% [markdown]
# - The 5 main features are: Lead_time, market_segment_type_Online, no_of_special_request, avg_price_per_room and no_of_adults.
#
#
# - The most important feature is lead_time. This is not shocking since there was a positive correlation between lead_time and booking status previously exposed.

# %% [markdown]
# ___

# %% [markdown]
# ### **7: Random Forest**

# %% [markdown]
# #### **7.1: Build a Random Forest Model**

# %%
rf_estimator = RandomForestClassifier()

rf_estimator.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# #### **7.2: Check the performance of the model on the train and test data**

# %%
y_pred_train_rf = rf_estimator.predict(X_train)

metrics_score(y_train, y_pred_train_rf )
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     17073
#            1       1.00      0.99      0.99      8319
#
#     accuracy                           0.99     25392
#    macro avg       0.99      0.99      0.99     25392
# weighted avg       0.99      0.99      0.99     25392

# %% [markdown]
# * Very few errors on the training set, almost all samples have been classified correctly.
# * Model has performed very well on the training set.
#
# * The Random Forest model has a better performance compared to Logistic Regression and SVM models.
#
# *  The Random Forest model is most likely overfitting. Let's check the performance on test data to see if the model is overfitting

# %%
y_pred_test_rf = rf_estimator.predict(X_test)

metrics_score(y_test, y_pred_test_rf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93      7317
#            1       0.88      0.80      0.84      3566
#
#     accuracy                           0.90     10883
#    macro avg       0.89      0.87      0.88     10883
# weighted avg       0.90      0.90      0.90     10883

# %% [markdown]
# - The model was overfitting. However, as in the Decision Tree, this Random Forest has a much better performace than the Logistic regression or SVM
#
# - It is able, without any correction, to have a Recall score of 80% and Precision of 88%. Thus, a very strong predictor.

# %% [markdown]
# #### **7.3: What are some important features based on the Random Forest?**

# %% [markdown]
# Let's check the feature importance of the Random Forest

# %%
importances = rf_estimator.feature_importances_

columns = X.columns

importance_df = pd.DataFrame(importances, index = columns, columns = ['Importance']).sort_values(by = 'Importance', ascending = False)

plt.figure(figsize = (13, 13))

sns.barplot(importance_df.Importance, importance_df.index)
# Out:
# <AxesSubplot:xlabel='Importance'>

# %% [markdown]
# - The Random Forest further verifies the results from the decision tree, that the most important features are lead time, average price per room, number of special request and arrival date.
# - Lead time is most important feature. If the customer booked the hotel too early there is an higher chance that he/she is most likely to cancel the booking.
#
# - The average price for a room is also a key feature, a low price for a room is a deal that it is hard to find, thus, the customer is unlikely to cancel.

# %% [markdown]
# ### **8: Conclude ANY FOUR key takeaways for business recommendations**

# %% [markdown]
# 1. Lead time is the most important features. We saw already in the correlation heatmap a strong positive correlation between the lead time and the Booking status. This implies an early prenotation is more subject to cancellation. Hence, it is possible to offer a discount or a limited promo in order to keep the customer interested.
#
# 2. Random forest is a very good estimator to obtain a consistent and reliable prediction about the Booking status. Thus, it may sound sensible to invest more computational resources on this particular model, in order to further improve its capabilities. Indeed, we have already a good precision and recall.
#
# 3. The average price for a room is a second strong feature to discriminate the Booking status. We saw in the decision tree that a small price for a room lead to lower cancellation. Thus, a good option to entice the customer to remain, is to have more rooms available for a low price.
#
# 4. In the reandom forest model, we see that there are many not important features. It may be advisable to eliminate and not consider the last 9 features for importance. This may save time for the data acquisition and data cleaning of new data points to expand and improve the dataset.
